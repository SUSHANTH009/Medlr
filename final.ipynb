# %%
import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
from collections import defaultdict
from sklearn.metrics.pairwise import cosine_similarity
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ### Filling packing_form column

# %%
def determine_packaging(salt):
    """Determine packaging form based on dosage information in salts"""
    if pd.isna(salt):
        return np.nan
    
    patterns = [
        (r'\b(mg|g|mcg)\b(?!.*/|\d+ml)', ['STRIP', 'Strip | Tablet', 'Strip TABLET', 'Strip | Capsule']),
        (r'\b(mg|g|mcg)/tablet\b', ['Strip | Tablet', 'STRIP']),
        (r'\b(mg|g|mcg)/ml\b', ['BOTTLE', 'Bottle | Suspension', 'Bottle SYRUP', 'Bottle | Syrup']),
        (r'\b%\s*(w/v|w/w)?\b', ['TUBE', 'BOTTLE', 'Bottle | Lotion']),
        (r'\b(iu|units?)/ml?\b', ['VIAL', 'AMPOULE', 'Vial | Injection']),
        (r'\b(ml|litre)\b', ['BOTTLE', 'Bottle | Solution', 'Bottle | Liquid']),
        (r'\b(injection|inj)\b', ['AMPOULE', 'Vial | Injection', 'INJECTION']),
        (r'\b(cream|ointment)\b', ['TUBE', 'Tube | Cream']),
        (r'\b(drops|solution)\b', ['Bottle | Drops', 'Bottle | Solution']),
        (r'\b(gel|shampoo)\b', ['Tube | Gel', 'Bottle | Shampoo']),
        (r'\b(powder|sachet)\b', ['SACHET', 'Packet | Suspension']),
    ]
    

    for pattern, packaging_options in patterns:
        if re.search(pattern, str(salt).lower()):

            for option in packaging_options:
                if option in valid_packaging:
                    return option
                

    return np.random.choice(['STRIP', 'BOTTLE', 'TUBE'], p=[0.5, 0.3, 0.2])


valid_packaging = [
    'STRIP', 'Strip | Tablet', 'Bottle | Suspension', 'BOTTLE',
    'Bottle SYRUP', 'Bottle | Syrup', 'Strip TABLET', 'AMPOULE',
    'Bottle | Infusion', 'Bottle | Oral Drops', 'Bottle | Spray',
    'INJECTION', 'TUBE', 'Vial | Injection', 'VIAL', 'Tube | Cream',
    'Bottle | Nasal Spray', 'Bottle | Nasal Drops', 'Tube | Gel',
    'Box | Injection', 'Tube | Mouth Gel', 'Tube GEL',
    'Bottle | Eye Drops', 'Vial INJECTION', 'Strip',
    'Bottle | Oral Suspension', 'Strip | Capsule', 'Tube',
    'Ampoule | Injection', 'Tube | Ointment', 'Packet | Injection',
    'Bottle', 'Bottle | Drops', 'Bottle | Solution', 'DRY VIAL',
    'Bottle | Oral Solution', 'Bottle | Eye/Ear Drops',
    'Bottle SUSPENSION', 'SACHET', 'Packet | Suspension', 'DEVICE',
    'BOX', 'Pack | Soap', 'Bottle | Dusting Powder', 'DROPS',
    'Tube | Shampoo', 'Bottle | Shampoo', 'CONTAINER',
    'Bottle | Lotion', 'PACK', 'PACKET', 'Bottle | Liquid',
    'Bottle | Tablet', 'Vial | Infusion', 'Bottle | Injection'
]

def fill_packaging_forms(df):
    """Main function to fill missing packaging forms"""

    df['salts'] = df['salts'].str.lower().fillna('')
    

    packaging_dist = df['packaging_form'].value_counts(normalize=True)
    

    mask = df['packaging_form'].isna()
    df.loc[mask, 'packaging_form'] = df.loc[mask, 'salts'].apply(
        lambda x: determine_packaging(x) if pd.notna(x) else np.random.choice(
            packaging_dist.index.tolist(), 
            p=packaging_dist.values.tolist()
        )
    )
    
    return df

# %% [markdown]
# ### standardizing salt column

# %%
def clean_salts_step1(salt):
    """Initial cleaning of salt strings."""
    if pd.isna(salt):
        return ""
    return salt.lower().strip()

def clean_salts_step2(salt):
    """Remove special characters, fix spacing, and standardize separators."""
    salt = re.sub(r'\b(na|n/a)\b', '', salt, flags=re.IGNORECASE) 
    salt = re.sub(r'[^a-z0-9.%/()+-,]', ' ', salt) 
    salt = re.sub(r'\s+', ' ', salt).strip() 
    salt = salt.replace('-', ' ')  
    salt = salt.replace('+', ',') 
    salt = re.sub(r'(\d+)\s*/\s*(\d+)', r'\1/\2', salt)  
    return salt


SALT_NAME_MAPPING = {
    'benzhexol hydrochloride': 'trihexyphenidyl',
    'trihexyphenidyl': 'trihexyphenidyl',
    'chlorpheniramine': 'chlorphenamine',
    'chlorphenamine maleate': 'chlorphenamine',
    'mecobalamin': 'vitamin b12',
    'cyanocobalamin': 'vitamin b12',
    'methylcobalamin': 'vitamin b12',
    'soluble insulin': 'human insulin',
    'linseed oil': 'linseed',
    'lignocaine': 'lidocaine',
    'hyoscine butylbromide': 'scopolamine',
    'vitamin d3': 'cholecalciferol',
    'benzhexol': 'trihexyphenidyl',
    'drotaverine': 'drotavarine',
    'levocloperastine fendizoate': 'levocloperastine',
    'serrati': 'serratiopeptidase',
    'serrat': 'serratiopeptidase',
    'diclofenac na': 'diclofenac',
    'na': '',
    'n/a': '',
    'acetaminophen': 'paracetamol',
    'rabeprazol': 'rabeprazole',
    'thiocolchic': 'thiocolchicoside',
    'mefenam': 'mefenamic acid',
    'piroxic': 'piroxicam',
    'chlorzox': 'chlorzoxazone'
}


def convert_to_mg(value, unit):
    """Convert grams to milligrams."""
    if 'g' == unit.lower() and not unit.startswith('m'):
        try:
            value_float = float(value)
            value = str(int(value_float * 1000))
            unit = 'mg'
        except ValueError:
            pass
    return value, unit


def process_salt_component(component):
    """Process a single salt component to standardize name and dosage."""
    component = component.strip().lower()
    dosage = None
    original_name = component


    paren_match = re.search(r'\((.*?)\)', component)
    if paren_match:
        dosage_str = paren_match.group(1)
        component = component.split('(')[0].strip()

        dosage_match = re.match(r'(\d+\.?\d*)\s*([a-z/%/0-9]+)', dosage_str)
        if dosage_match:
            value = dosage_match.group(1)
            unit = dosage_match.group(2).replace(' ', '')

            if '.' in value:
                value = value.rstrip('0').rstrip('.')

            value, unit = convert_to_mg(value, unit)
            dosage = f"{value}{unit}"
    else:

        dosage_match = re.search(r'(\d+\.?\d*)\s*([a-z/%/0-9]+)\s*$', component)
        if dosage_match:
            value = dosage_match.group(1)
            unit = dosage_match.group(2).replace(' ', '')
            if '.' in value:
                value = value.rstrip('0').rstrip('.')

            value, unit = convert_to_mg(value, unit)
            dosage = f"{value}{unit}"
            component = component[:dosage_match.start()].strip()


    alternatives = [a.strip() for a in component.split('/')]
    primary_name = None


    for alt in alternatives:
        if alt in SALT_NAME_MAPPING:
            primary_name = SALT_NAME_MAPPING[alt]
            break


    if not primary_name:
        primary_name = alternatives[0]

        primary_name = SALT_NAME_MAPPING.get(primary_name, primary_name)

    if dosage:
        dosage = re.sub(r'%w/w?/?v?', '%', dosage)  # Standardize percentages
        dosage = re.sub(r'gms?', 'mg', dosage)  # Standardize grams to mg

    # Remove redundant strength info
    primary_name = re.sub(r'\s+(\d+\.?\d*)\s*[a-z/%]+$', '', primary_name).strip()

    # Combine name and dosage
    if dosage and dosage != '0':
        return f"{primary_name} {dosage}"
    return primary_name

# Function to process the entire salts string
def process_salts(salt_str):
    """Process the entire salts string by splitting and processing components."""
    if pd.isna(salt_str) or not str(salt_str).strip():
        return salt_str

    components = [c.strip() for c in str(salt_str).split(',')]
    processed = []

    for comp in components:
        processed_comp = process_salt_component(comp)
        if processed_comp:
            processed.append(processed_comp)

    return ', '.join(processed)

# %%
class FormulationClusterer:
    def __init__(self):
        # Use a biomedical sentence transformer model
        self.model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
        
    def preprocess(self, texts):
        """Standardize formulation strings"""
        processed = []
        for text in texts:
            text = str(text).lower().replace('%', ' percent').replace('/', ' per ')
            text = re.sub(r'[^a-z0-9\s]', ' ', text)
            text = re.sub(r'\s+', ' ', text).strip()
            processed.append(text)
        return processed
    
    def get_embeddings(self, texts):
        """Convert text to embeddings"""
        return self.model.encode(texts, convert_to_tensor=True).cpu().numpy()
    
    def cluster_formulations(self, formulations, threshold=0.3):
        """Perform hierarchical clustering"""
        cleaned = self.preprocess(formulations)
        embeddings = self.get_embeddings(cleaned)
        
        dist_matrix = 1 - cosine_similarity(embeddings)
        
        linkage_matrix = linkage(dist_matrix, 'average')
        
        clusters = fcluster(linkage_matrix, threshold, criterion='distance')
        
        return clusters, linkage_matrix

    def print_clusters(self, formulations, clusters):
        """Display clustered formulations"""
        cluster_dict = defaultdict(list)
        for formulation, cluster_id in zip(formulations, clusters):
            cluster_dict[cluster_id].append(formulation)
            
        for cluster_id, members in cluster_dict.items():
            print(f"\nCluster {cluster_id}:")
            print("-" * 40)
            print("\n".join(members))

# %%
df = pd.read_csv('medlr_assignment_dataset.csv')

df['salts'] = df['salts'].apply(clean_salts_step1)
df['salts'] = df['salts'].apply(clean_salts_step2)
df['salts'] = df['salts'].str.lower().apply(process_salts)

df = fill_packaging_forms(df)

df["salts"] = df["salts"].fillna("Unknown")
df = df[df["salts"] != "Unknown"]

sample_salts = df["salts"].unique().tolist()

clusterer = FormulationClusterer()
clusters, linkage_matrix = clusterer.cluster_formulations(sample_salts)

# Assign clusters to DataFrame
cluster_mapping = {salt: cluster for salt, cluster in zip(sample_salts, clusters)}
df["cluster"] = df["salts"].map(cluster_mapping)


# Print clustered results
clusterer.print_clusters(sample_salts, clusters)
# Out:
# Cluster 100:
# ----------------------------------------
# paracetamol 1000mg
#
# Cluster 102:
# ----------------------------------------
# paracetamol 120mg
# paracetamol 150mg
# paracetamol 125mg
#
# Cluster 91:
# ----------------------------------------
# paracetamol 120mg/5ml
# paracetamol 250mg/5ml
# paracetamol 125mg/5ml
#
# Cluster 132:
# ----------------------------------------
# paracetamol 5ml
#
# Cluster 92:
# ----------------------------------------
# paracetamol 156.25mg/5ml
#
# Cluster 104:
# ----------------------------------------
# paracetamol 156.25mg
#
# Cluster 103:
# ----------------------------------------
# paracetamol 250mg
#
# Cluster 98:
# ----------------------------------------
# paracetamol 500mg
#
# Cluster 99:
# ----------------------------------------
# paracetamol 650mg
#
# Cluster 101:
# ----------------------------------------
# paracetamol 100mg
#
# Cluster 151:
# ----------------------------------------
# phenylephrine 10mg, chlorphenamine 2mg, paracetamol 325mg
#
# Cluster 148:
# ----------------------------------------
# chlorphenamine 50mg, pseudoephedrine 50mg, paracetamol 50mg
#
# Cluster 113:
# ----------------------------------------
# paracetamol 500mg, caffeine 30mg, phen
#
# Cluster 28:
# ----------------------------------------
# xylometazoline
#
# Cluster 143:
# ----------------------------------------
# caffeine 30mg, phenylephrine 10mg, chlorphenamine 2mg, paracetamol 500mg
# caffeine 30mg, chlorphenamine 2mg, paracetamol 325mg, phenylephrine 10mg
#
# Cluster 40:
# ----------------------------------------
#
#
# Cluster 141:
# ----------------------------------------
# chlorphenamine, paracetamol, pseudoephedrine
#
# Cluster 93:
# ----------------------------------------
# paracetamol 100mg/ml
#
# Cluster 301:
# ----------------------------------------
# dicyclomine, mefenamic acid
#
# Cluster 157:
# ----------------------------------------
# diclofenac 50mg
#
# Cluster 302:
# ----------------------------------------
# drotavarine, mefenamic acid
#
# Cluster 73:
# ----------------------------------------
# mefenamic acid 100mg/5ml, paracetamol 250mg/5ml
# mefenamic acid 50mg/5ml, paracetamol 125mg/5ml
#
# Cluster 74:
# ----------------------------------------
# paracetamol 125mg/5ml, mefenamic acid 50mg/5ml
#
# Cluster 72:
# ----------------------------------------
# mefenamic acid 50mg, paracetamol 125mg
# mefenamic acid 100mg, paracetamol 250mg
#
# Cluster 71:
# ----------------------------------------
# mefenamic acid 100mg, paracetamol 250
# mefenamic acid 100mg, paracetamol 125
#
# Cluster 383:
# ----------------------------------------
# diclofenac 1.16%, menthol 5%, methyl salicylate 10%, linseed 3%
# diclofenac 1.16%, linseed 3%, menthol 5%, methyl salicylate 10%
# diclofenac 1%, linseed 3%, menthol 5%, methyl salicylate 10%
#
# Cluster 59:
# ----------------------------------------
# diclofenac 50mg, paracetamol 500mg
# diclofenac 50mg, paracetamol 650mg
#
# Cluster 228:
# ----------------------------------------
# nimesulide 100mg, tizanidine 2mg
#
# Cluster 105:
# ----------------------------------------
# tramadol 37.5mg, paracetamol 325mg
#
# Cluster 107:
# ----------------------------------------
# paracetamol 325mg, tramadol 37.5mg
#
# Cluster 47:
# ----------------------------------------
# paracetamol 500mg, thiocolchicoside 4mg
#
# Cluster 110:
# ----------------------------------------
# caffeine 50mg, paracetamol 650mg
#
# Cluster 160:
# ----------------------------------------
# diclofenac 25mg
#
# Cluster 394:
# ----------------------------------------
# diclofenac 1.16%
# diclofenac 1.16% w
#
# Cluster 210:
# ----------------------------------------
# beclomethasone, clotrimazole
#
# Cluster 50:
# ----------------------------------------
# chlorzoxazone 250mg, diclofenac 46.5mg, paracetamol
# chlorzoxazone 250mg, diclofenac 50mg, paracetamol
#
# Cluster 51:
# ----------------------------------------
# chlorzoxazone 250mg, diclofenac 46.5mg, paracetamol 500mg
# chlorzoxazone 500mg, diclofenac 50mg, paracetamol 325mg
# chlorzoxazone 250mg, diclofenac 50mg, paracetamol 325mg
# chlorzoxazone 200mg, diclofenac 50mg, paracetamol 325mg
# chlorzoxazone 250mg, diclofenac 50mg, paracetamol 500mg
# chlorzoxazone 250mg, diclofenac 200mg, paracetamol 325mg
#
# Cluster 133:
# ----------------------------------------
# chlorzoxazone, diclofenac sodium, paracetamol
#
# Cluster 136:
# ----------------------------------------
# diclofenac sodium, paracetamol
#
# Cluster 360:
# ----------------------------------------
# diclofenac, linseed, menthol, methyl salicylate
#
# Cluster 264:
# ----------------------------------------
# piroxicam 20mg
#
# Cluster 266:
# ----------------------------------------
# piroxicam 40mg
#
# Cluster 69:
# ----------------------------------------
# paracetamol 325mg, piroxicam 20mg
#
# Cluster 48:
# ----------------------------------------
# aceclofenac 100mg, chlorzoxazone 250mg, paracetamol 325mg
# aceclofenac 100mg, chlorzoxazone 250mg, paracetamol 500mg
# aceclofenac 100mg, paracetamol 500mg, chlorzoxazone 250mg
# aceclofenac 100mg, paracetamol 325mg, chlorzoxazone 250mg
# aceclofenac 100mg, paracetamol 325mg, chlorzoxazone 500mg
# aceclofenac 100mg, chlorzoxazone 500mg, paracetamol 325mg
#
# Cluster 42:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 325mg, serratiopeptidase 15mg
# aceclofenac 100mg, paracetamol 500mg, serratiopeptidase 15mg
# aceclofenac 100mg, serratiopeptidase 15mg, paracetamol 325mg
# aceclofenac 100mg, paracetamol 325mg, serratiopeptidase 10mg
#
# Cluster 89:
# ----------------------------------------
# paracetamol 100mg, chlormezanone 450mg
#
# Cluster 90:
# ----------------------------------------
# paracetamol 450mg, chlormezanone 100m
#
# Cluster 158:
# ----------------------------------------
# diclofenac 100mg
#
# Cluster 159:
# ----------------------------------------
# diclofenac 75mg
#
# Cluster 180:
# ----------------------------------------
# tizanidine 2mg, diclofenac 50mg
#
# Cluster 122:
# ----------------------------------------
# chlorzoxazone, nimesulide, paracetamol
#
# Cluster 123:
# ----------------------------------------
# nimesulide, paracetamol
#
# Cluster 164:
# ----------------------------------------
# diclofenac 50mg, serratiopeptidase 15mg
# diclofenac 50mg, serratiopeptidase 10mg
#
# Cluster 134:
# ----------------------------------------
# chlorzoxazone, diclofenac, paracetamol
#
# Cluster 178:
# ----------------------------------------
# aceclofenac 100mg
#
# Cluster 176:
# ----------------------------------------
# aceclofenac 200mg
#
# Cluster 55:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 500mg
# aceclofenac 50mg, paracetamol 125mg
# aceclofenac 100mg, paracetamol 650mg
# aceclofenac 100mg, paracetamol 125mg
#
# Cluster 355:
# ----------------------------------------
# aceclofenac, paracetamol, serratiopeptidase
#
# Cluster 361:
# ----------------------------------------
# diclofenac, menthol, methyl salicylate
#
# Cluster 186:
# ----------------------------------------
# diclofenac 100mg, rabeprazole 20mg
#
# Cluster 41:
# ----------------------------------------
# diclofenac 50mg, paracetamol 325mg, serratiopeptidase 15mg
# diclofenac 50mg, paracetamol 325mg, serratiopeptidase 10mg
# diclofenac 50mg, serratiopeptidase 10mg, paracetamol 325mg
# diclofenac 200mg, paracetamol 325mg, serratiopeptidase 10mg
#
# Cluster 288:
# ----------------------------------------
# prilocaine 25mg/mg, lidocaine 25mg/mg
#
# Cluster 257:
# ----------------------------------------
# prilocaine 2.5%, lidocaine 2.5%
# lidocaine 2.5%, prilocaine 2.5%
#
# Cluster 289:
# ----------------------------------------
# lidocaine 25mg, prilocaine 25mg
#
# Cluster 396:
# ----------------------------------------
# diclofenac sodium
#
# Cluster 25:
# ----------------------------------------
# piroxicam
#
# Cluster 308:
# ----------------------------------------
# cefradine 250mg
#
# Cluster 309:
# ----------------------------------------
# cefuroxime 500mg
#
# Cluster 130:
# ----------------------------------------
# paracetamol, tramadol
#
# Cluster 56:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 325mg
#
# Cluster 398:
# ----------------------------------------
# diclofenac potassium
#
# Cluster 137:
# ----------------------------------------
# diclofenac, paracetamol
#
# Cluster 209:
# ----------------------------------------
# xylometazoline 200mg
#
# Cluster 146:
# ----------------------------------------
# chlorpheniramine maleate 2mg, paracetamol
# chlorpheniramine maleate 1mg, paracetamol
#
# Cluster 150:
# ----------------------------------------
# chlorphenamine 2mg, paracetamol 250mg, phenylephrine 5mg
# chlorphenamine 1mg, paracetamol 125mg, phenylephrine 2.5mg
#
# Cluster 152:
# ----------------------------------------
# chlorpheniramine maleate 2mg, phenylephrine 5mg, paracetamol 250mg
#
# Cluster 27:
# ----------------------------------------
# xylometazoline 0.05% w
# xylometazoline 0.05%
#
# Cluster 145:
# ----------------------------------------
# caffeine 30mg, chlorpheniramine maleate 2mg, paracetamol 500mg, phenylephrine hydrochloride 10mg
#
# Cluster 385:
# ----------------------------------------
# diclofenac 1%, linseed 3%, menthol 1%, salicylic acid 10%
#
# Cluster 399:
# ----------------------------------------
# diclofenac
#
# Cluster 286:
# ----------------------------------------
# tramadol 100mg
#
# Cluster 287:
# ----------------------------------------
# tramadol 50mg
#
# Cluster 32:
# ----------------------------------------
# tramadol
#
# Cluster 167:
# ----------------------------------------
# aceclofenac 100mg, thiocolchicoside 4mg
#
# Cluster 388:
# ----------------------------------------
# aceclofenac, thiocolchicoside
#
# Cluster 119:
# ----------------------------------------
# aceclofenac, paracetamol
#
# Cluster 83:
# ----------------------------------------
# ibuprofen 400mg, paracetamol 325mg, magnesium trisilicate 100mg
#
# Cluster 77:
# ----------------------------------------
# ibuprofen 100mg, paracetamol 162.5mg
#
# Cluster 282:
# ----------------------------------------
# ibuprofen
#
# Cluster 384:
# ----------------------------------------
# diclofenac sodium 1%, linseed 3%, menthol 5%, methyl salicylate 10%
#
# Cluster 24:
# ----------------------------------------
# nimesulide, tizanidine
#
# Cluster 68:
# ----------------------------------------
# nimesulide 100mg, paracetamol 500mg
#
# Cluster 22:
# ----------------------------------------
# nimesulide
#
# Cluster 381:
# ----------------------------------------
# diclofenac diethylamine 1.16%, linseed 3%, menthol 5%, methyl salicylate 10%
# diclofenac diethylamine 1.16%, linseed 3%, methyl salicylate 10%, menthol 5%
#
# Cluster 53:
# ----------------------------------------
# chlorzoxazone 250mg, aceclofenac 100mg, paracetamol 325mg
#
# Cluster 78:
# ----------------------------------------
# ibuprofen 100mg, paracetamol 125mg
#
# Cluster 265:
# ----------------------------------------
# piroxicam 10mg
#
# Cluster 281:
# ----------------------------------------
# gabapentin 300mg
#
# Cluster 364:
# ----------------------------------------
# choline salicylate 8.7%, lidocaine 2%
#
# Cluster 366:
# ----------------------------------------
# benzalkonium chloride 0.01%, choline salicylate 8.7%, lignocaine hydrochloride 2%
# benzalkonium chloride 0.01%, choline salicylate 8.7% w, lignocaine hydrochloride 2%
#
# Cluster 365:
# ----------------------------------------
# choline salicylate 8.7% w, lidocaine 2% w
#
# Cluster 367:
# ----------------------------------------
# benzalkonium chloride 0.01%, choline salicylate 8.7%, lidocaine 2%
#
# Cluster 161:
# ----------------------------------------
# eperisone 50mg, diclofenac 50mg
#
# Cluster 397:
# ----------------------------------------
# diclofenac sodium, eperisone
#
# Cluster 356:
# ----------------------------------------
# diclofenac, paracetamol, serratiopeptidase
#
# Cluster 60:
# ----------------------------------------
# diclofenac 50mg, paracetamol 325mg
# diclofenac 200mg, paracetamol 325mg
# diclofenac 50mg, paracetamol 325mg, se
#
# Cluster 299:
# ----------------------------------------
# mefenamic acid 500mg
#
# Cluster 357:
# ----------------------------------------
# paracetamol, propoxyphene
#
# Cluster 96:
# ----------------------------------------
# paracetamol 650mg, codeine 30mg
#
# Cluster 97:
# ----------------------------------------
# codeine 30mg, paracetamol 650mg
#
# Cluster 10:
# ----------------------------------------
# ketorolac 0.5%
#
# Cluster 11:
# ----------------------------------------
# ketorolac 0.4%
#
# Cluster 187:
# ----------------------------------------
# ofloxacin 0.3%, ketorolac 0.4%
#
# Cluster 188:
# ----------------------------------------
# ketorolac 4mg, ofloxacin 3mg
#
# Cluster 154:
# ----------------------------------------
# diclofenac sodium 75mg/ml
#
# Cluster 284:
# ----------------------------------------
# carmellose, flurbiprofen
#
# Cluster 293:
# ----------------------------------------
# flurbiprofen 0.03mg/5ml, hypromellose 0.25% w
#
# Cluster 378:
# ----------------------------------------
# methylsalicylate 5%, menthol 5%, capsaicin 0.025%, diclofenac 1.16%
#
# Cluster 371:
# ----------------------------------------
# capsaicin 0.025%, diclofenac 1%, menthol 5%, methyl salicylate 5%
#
# Cluster 49:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 325mg, chlorzoxazon
#
# Cluster 389:
# ----------------------------------------
# aceclofenac, glucosamine, methyl sulfonylmethane
#
# Cluster 84:
# ----------------------------------------
# scopolamine 10mg, paracetamol
#
# Cluster 124:
# ----------------------------------------
# hyoscyamine, paracetamol
#
# Cluster 94:
# ----------------------------------------
# hyoscyamine 10mg, paracetamol
#
# Cluster 285:
# ----------------------------------------
# hyoscine butylbromide
#
# Cluster 323:
# ----------------------------------------
# butylscopolamine 20mg
#
# Cluster 311:
# ----------------------------------------
# scopolamine 20mg
#
# Cluster 95:
# ----------------------------------------
# hyoscine 10mg, paracetamol 500mg
#
# Cluster 85:
# ----------------------------------------
# scopolamine 10mg, paracetamol 500mg
#
# Cluster 391:
# ----------------------------------------
# aceclofenac 200 mg sustained release
#
# Cluster 372:
# ----------------------------------------
# capsaicin 0.025%, menthol 5%, diclofenac sodium 1%, methyl salicylate 5%
#
# Cluster 211:
# ----------------------------------------
# dextromethorphan
#
# Cluster 329:
# ----------------------------------------
# dexchlorpheniramine 4mg, dextromethorphan 10mg
#
# Cluster 392:
# ----------------------------------------
# chlorphenamine, codeine
#
# Cluster 258:
# ----------------------------------------
# diacerein 50mg
#
# Cluster 33:
# ----------------------------------------
# diacerein
#
# Cluster 63:
# ----------------------------------------
# thiocolchicoside 4mg, aceclofenac 100mg, paracetamol 325mg
# thiocolchicoside 8mg, aceclofenac 100mg, paracetamol 325mg
#
# Cluster 328:
# ----------------------------------------
# doxofylline 650mg
#
# Cluster 312:
# ----------------------------------------
# etoricoxib 90mg
#
# Cluster 125:
# ----------------------------------------
# mefenamic acid, paracetamol
#
# Cluster 330:
# ----------------------------------------
# etoricoxib 60mg, thiocolchicoside 4mg
#
# Cluster 81:
# ----------------------------------------
# ibuprofen 400mg, methionine 50mg, paracetamol 500mg
#
# Cluster 82:
# ----------------------------------------
# ibuprofen 400mg, methionine 50mg, paracetamol
#
# Cluster 126:
# ----------------------------------------
# ibuprofen, paracetamol
#
# Cluster 79:
# ----------------------------------------
# ibuprofen 400mg, paracetamol 325mg
# ibuprofen 600mg, paracetamol 325mg
#
# Cluster 80:
# ----------------------------------------
# ibuprofen 400mg, paracetamol 500mg
#
# Cluster 34:
# ----------------------------------------
# pain relif
#
# Cluster 75:
# ----------------------------------------
# chlorzoxazone 250mg, ibuprofen 400mg, paracetamol 325mg
#
# Cluster 76:
# ----------------------------------------
# ibuprofen 400mg, paracetamol 325mg, chlorzoxazone 250mg
#
# Cluster 171:
# ----------------------------------------
# thiocolchicoside 4mg, diclofenac 200mg
#
# Cluster 350:
# ----------------------------------------
# doxylamine, vitamin b6
#
# Cluster 144:
# ----------------------------------------
# caffeine 30mg, diphenhydramine 25mg, paracetamol 325mg, phenylephrine 5mg
#
# Cluster 162:
# ----------------------------------------
# diclofenac 50mg, tolperisone 150mg
#
# Cluster 138:
# ----------------------------------------
# diclofenac potassium, paracetamol
#
# Cluster 387:
# ----------------------------------------
# diclofenac sodium 1%, linseed oil, menthol 5%
#
# Cluster 358:
# ----------------------------------------
# benzyl alcohol, diclofenac, menthol, methyl salicylate
#
# Cluster 280:
# ----------------------------------------
# vitamin b12 500mcg, gabapentin 100mg
#
# Cluster 279:
# ----------------------------------------
# gabapentin 100mg, vitamin b12 500mcg
# gabapentin 300mg, vitamin b12 500mcg
#
# Cluster 278:
# ----------------------------------------
# nortriptyline 10mg, gabapentin 100mg
#
# Cluster 276:
# ----------------------------------------
# gabapentin 100mg, nortriptyline 10mg
# gabapentin 400mg, nortriptyline 10mg
#
# Cluster 277:
# ----------------------------------------
# gabapentin 200mg, nortriptyline 10mg
#
# Cluster 351:
# ----------------------------------------
# vitamin b12 750mcg, pregabalin 75mg
#
# Cluster 267:
# ----------------------------------------
# piroxicam 5mg
#
# Cluster 314:
# ----------------------------------------
# etoricoxib 120mg
#
# Cluster 313:
# ----------------------------------------
# etoricoxib 60mg
#
# Cluster 26:
# ----------------------------------------
# piroxicam 0.5%
#
# Cluster 268:
# ----------------------------------------
# piroxicam 20mg/ml
#
# Cluster 155:
# ----------------------------------------
# diclofenac sodium 75mg
#
# Cluster 156:
# ----------------------------------------
# diclofenac 25mg/ml
# diclofenac 75mg/ml
#
# Cluster 222:
# ----------------------------------------
# nimesulide 100mg
#
# Cluster 226:
# ----------------------------------------
# nimesulide 200mg
#
# Cluster 223:
# ----------------------------------------
# nimesulide 50mg
#
# Cluster 38:
# ----------------------------------------
# aconitum napellus dh20 2. arsenicum album dh18 3. asafoetida dh20 4. calcarea carbonica dh16 5. conium maculatum . ipecacuanha dh13 7phosphoru
#
# Cluster 112:
# ----------------------------------------
# caffeine 25mg, paracetamol 325mg
#
# Cluster 131:
# ----------------------------------------
# paracetamol
#
# Cluster 127:
# ----------------------------------------
# paracetamol, caffeine, phenylephrine
#
# Cluster 373:
# ----------------------------------------
# capsaicin 0.025%, diclofenac sodium 1%, linseed 3%, menthol 5%, methyl salicylate 10%
#
# Cluster 128:
# ----------------------------------------
# caffeine, paracetamol
#
# Cluster 376:
# ----------------------------------------
# menthol 5%, methyl salicylate 10%, capsaicin 0.025%, linseed 1%, diclofenac 1.16%
#
# Cluster 115:
# ----------------------------------------
# caffeine, paracetamol 10mg
#
# Cluster 111:
# ----------------------------------------
# caffeine 25mg, paracetamol 500mg
#
# Cluster 114:
# ----------------------------------------
# paracetamol 500mg, caffeine 25mg
#
# Cluster 62:
# ----------------------------------------
# diclofenac 50mg, paracetamol 250mg, dextropropoxyphene 32.5mg
#
# Cluster 139:
# ----------------------------------------
# dextropropoxyphene, diclofenac, paracetamol
#
# Cluster 153:
# ----------------------------------------
# diclofenac 50mg, paracetamol 325mg, chlorpheniramine maleate 4mg, magnesium trisilicate 100mg
#
# Cluster 142:
# ----------------------------------------
# chlorphenamine, diclofenac sodium, magnesium trisilicate, paracetamol
#
# Cluster 333:
# ----------------------------------------
# pentazocine 30mg
#
# Cluster 352:
# ----------------------------------------
# heparin 0.01mg, diclofenac 200iu
#
# Cluster 310:
# ----------------------------------------
# duloxetine 20mg
#
# Cluster 6:
# ----------------------------------------
# prednisolone 1%
#
# Cluster 7:
# ----------------------------------------
# prednisolon 1%
#
# Cluster 395:
# ----------------------------------------
# diclofenac 1%
#
# Cluster 165:
# ----------------------------------------
# aceclofenac 100mg, serratiopeptidase 15mg
#
# Cluster 390:
# ----------------------------------------
# aceclofenac
#
# Cluster 166:
# ----------------------------------------
# aceclofenac 100mg, thiocolchicoside 8mg
# aceclofenac 200mg, thiocolchicoside 8mg
#
# Cluster 116:
# ----------------------------------------
# caffeine 50mg, domperidone 10mg, paracetamol 650mg
#
# Cluster 117:
# ----------------------------------------
# caffeine 50mg, domperidone 10mg, paracetamol
#
# Cluster 129:
# ----------------------------------------
# caffeine, domperidone, paracetamol
#
# Cluster 353:
# ----------------------------------------
# sucralfate 1mg, oxetacaine 10mg
#
# Cluster 335:
# ----------------------------------------
# rofecoxib 12.5mg
#
# Cluster 336:
# ----------------------------------------
# rofecoxib 25mg
#
# Cluster 337:
# ----------------------------------------
# rofecoxib 50mg
#
# Cluster 61:
# ----------------------------------------
# diclofenac 25mg, paracetamol 75mg
#
# Cluster 135:
# ----------------------------------------
# chlorzoxazone, diclofenac potassium, paracetamol
#
# Cluster 108:
# ----------------------------------------
# tramadol 37.5mg, domperidone 10mg, paracetamol 325mg
#
# Cluster 43:
# ----------------------------------------
# serratiopeptidase 10mg, aceclofenac 100mg, paracetamol 325mg
#
# Cluster 64:
# ----------------------------------------
# aceclofenac 100mg, thiocolchicoside 4mg, paracetamol 325mg
# aceclofenac 100mg, thiocolchicoside 8mg, paracetamol 325mg
# aceclofenac 100mg, paracetamol 325mg, thiocolchicoside 4mg
# aceclofenac 100mg, paracetamol 325mg, thiocolchicoside 8mg
#
# Cluster 377:
# ----------------------------------------
# aceclofenac 1.5%, capsaicin 0.01%, linseed 3%, menthol 5%, methyl salicylate 10%
#
# Cluster 341:
# ----------------------------------------
# gloria superba 8mg, boswelia serrata 400mg, curcuma longa 25mg
#
# Cluster 58:
# ----------------------------------------
# aceclofenac 100mg/5ml, paracetamol 12
#
# Cluster 324:
# ----------------------------------------
# tapentadol 50mg
#
# Cluster 118:
# ----------------------------------------
# domperidone 10mg, paracetamol 325mg, t
#
# Cluster 67:
# ----------------------------------------
# nimesulide 100mg, paracetamol 375mg
# nimesulide 100mg, paracetamol 325mg
#
# Cluster 70:
# ----------------------------------------
# lornoxicam 8mg, paracetamol 325mg
#
# Cluster 183:
# ----------------------------------------
# aceclofenac 200mg, rabeprazole 20mg
#
# Cluster 163:
# ----------------------------------------
# dicyclomine 10mg, simethicone 40mg
#
# Cluster 220:
# ----------------------------------------
# dicyclomine 20mg, nimesulide 100mg
#
# Cluster 393:
# ----------------------------------------
# dicycloverine hydrochloride
#
# Cluster 292:
# ----------------------------------------
# dexketoprofen 75mg
#
# Cluster 109:
# ----------------------------------------
# paracetamol 325mg, tramadol hydrochloride 37.5mg
#
# Cluster 283:
# ----------------------------------------
# dexketoprofen
#
# Cluster 221:
# ----------------------------------------
# nimesulide 100mg, dicycloverine 20mg
#
# Cluster 44:
# ----------------------------------------
# dicyclomine 20mg, paracetamol 325mg
#
# Cluster 45:
# ----------------------------------------
# dicyclomine 20mg, paracetamol 500mg
#
# Cluster 140:
# ----------------------------------------
# dicycloverine, paracetamol
#
# Cluster 46:
# ----------------------------------------
# dicycloverine 20mg, paracetamol 500mg
#
# Cluster 300:
# ----------------------------------------
# mefenamic acid 250mg
#
# Cluster 374:
# ----------------------------------------
# diclofenac 1.16%, methyl salicylate 5%, menthol 5%, linseed 3%, capsaicin 0.025%
#
# Cluster 66:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 325mg, rabeprazole 10mg
#
# Cluster 362:
# ----------------------------------------
# capsaicin, diclofenac, linseed, menthol, methyl salcylate
#
# Cluster 185:
# ----------------------------------------
# rabeprazole 20mg, aceclofenac 200mg
#
# Cluster 120:
# ----------------------------------------
# aceclofenac, paracetamol, rabeprazole
#
# Cluster 375:
# ----------------------------------------
# diclofenac 1.16%, capsaicin 0.01%, methyl salicylate 10%, menthol 5%, linseed 3%
#
# Cluster 363:
# ----------------------------------------
# capsicum oleoresin, menthol, methyl salcylate, piroxicam
#
# Cluster 331:
# ----------------------------------------
# levocloperastine 20mg
#
# Cluster 332:
# ----------------------------------------
# levocloperastine 20mg/5ml
#
# Cluster 340:
# ----------------------------------------
# valdecoxib 10mg
#
# Cluster 322:
# ----------------------------------------
# nandrolone decanoate 50mg
#
# Cluster 379:
# ----------------------------------------
# aloe vera 2%, diclofenac sodium 1%, menthol 5%, methyl salicylate 15%
#
# Cluster 380:
# ----------------------------------------
# diclofenac 1.16%, menthol 5%, methyl salicylate 15%, aloe vera 2%
#
# Cluster 184:
# ----------------------------------------
# aceclofenac 100mg, rabeprazole 20mg
#
# Cluster 174:
# ----------------------------------------
# aceclofenac 200mg, pregabalin 75mg
# aceclofenac 200mg, pregabalin 150mg
#
# Cluster 359:
# ----------------------------------------
# benzyl alcohol, diclofenac diethylamine, menthol, methyl salicylate, oleum
#
# Cluster 400:
# ----------------------------------------
# diclofenac potassium, serratiopeptidase
#
# Cluster 386:
# ----------------------------------------
# methyl salicylate 10%, linseed 3%, diclofen diethylamine 1.16%, menthol 5%
#
# Cluster 370:
# ----------------------------------------
# methyl salicylate 10%, menthol 5%, capsaicin 0.025%, linseed 3%
#
# Cluster 368:
# ----------------------------------------
# capsaicin 0.025%, diclofenac diethylamine 1.16%, menthol 5%, methyl salicylate 10%, virgin linseed oil 3%
#
# Cluster 177:
# ----------------------------------------
# aceclofenac 150mg
#
# Cluster 369:
# ----------------------------------------
# capsaicin 0.025%, diclofenac 1%, menthol 5%, methyl salicylate 10%, virgin linseed oil 3%
#
# Cluster 29:
# ----------------------------------------
# pentazocine
#
# Cluster 172:
# ----------------------------------------
# drotavarine 80mg, aceclofenac 100mg
#
# Cluster 173:
# ----------------------------------------
# aceclofenac 100mg, drotavarine 80mg
#
# Cluster 106:
# ----------------------------------------
# tramadol 50mg, paracetamol 500mg
#
# Cluster 294:
# ----------------------------------------
# amoxycillin 1000mg, clavulanic acid 200mg
# amoxycillin 400mg, clavulanic acid 57mg
#
# Cluster 295:
# ----------------------------------------
# amoxycillin 250mg, clavulanic acid 125mg
# amoxycillin 200mg, clavulanic acid 28.5mg
#
# Cluster 297:
# ----------------------------------------
# amoxicillin 500mg, clavulanate 125mg
#
# Cluster 298:
# ----------------------------------------
# amoxycillin 500mg, clavulanic acid 125mg, lactobacillus 60million
#
# Cluster 296:
# ----------------------------------------
# amoxycillin 80mg, clavulanic acid 11.4mg
#
# Cluster 219:
# ----------------------------------------
# serratiopeptidase 10mg
#
# Cluster 181:
# ----------------------------------------
# diclofenac 50mg, tizanidine 2mg
#
# Cluster 54:
# ----------------------------------------
# diclofenac sodium 50mg, chlorzoxazone 250mg, paracetamol 325mg
#
# Cluster 52:
# ----------------------------------------
# diclofenac 50mg, chlorzoxazone 250mg, paracetamol 325mg
#
# Cluster 147:
# ----------------------------------------
# chlorpheniramine maleate 5mg, paracetamol
#
# Cluster 149:
# ----------------------------------------
# chlorphenamine 5mg, paracetamol 500mg
#
# Cluster 179:
# ----------------------------------------
# aceclofenac 150mg/ml
#
# Cluster 382:
# ----------------------------------------
# aceclofenac 1.5%, linseed 3%, menthol 1.25%, methyl salicylate 2.5%
# aceclofenac 1.5%, linseed 3%, menthol 5%, methyl salicylate 10%
#
# Cluster 182:
# ----------------------------------------
# aceclofenac 100mg, tizanidine 2mg
#
# Cluster 57:
# ----------------------------------------
# paracetamol 325mg, aceclofenac 100mg
#
# Cluster 175:
# ----------------------------------------
# pregabalin 150mg, aceclofenac 200mg
#
# Cluster 65:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 325mg, tramadol 37.5mg
# aceclofenac 100mg, tramadol 37.5mg, paracetamol 325mg
#
# Cluster 121:
# ----------------------------------------
# aceclofenac 100mg, paracetamol 325mg, trypsin chymotrypsin 150000au
#
# Cluster 169:
# ----------------------------------------
# thiocolchicoside 16mg, aceclofenac 200mg
#
# Cluster 170:
# ----------------------------------------
# aceclofenac 16mg, thiocolchicoside 16mg
#
# Cluster 168:
# ----------------------------------------
# aceclofenac 200mg, thiocolchicoside 16mg
#
# Cluster 342:
# ----------------------------------------
# boswelia serrata extract 50mg, curcuma longa rhizome extract 400mg
#
# Cluster 343:
# ----------------------------------------
# nano curcumin 500mg, piperine 5mg
#
# Cluster 215:
# ----------------------------------------
# nano curcumin, piperine
#
# Cluster 325:
# ----------------------------------------
# docetaxel 120mg
#
# Cluster 327:
# ----------------------------------------
# docetaxel 20mg
#
# Cluster 31:
# ----------------------------------------
# docetaxel
#
# Cluster 326:
# ----------------------------------------
# docetaxel 80mg
#
# Cluster 224:
# ----------------------------------------
# nimesulide 10mg
#
# Cluster 227:
# ----------------------------------------
# nimesulide 10mg/mg
#
# Cluster 225:
# ----------------------------------------
# nimesulide 75mg
#
# Cluster 217:
# ----------------------------------------
# nimesulide 100mg, serratiopeptidase 15mg
#
# Cluster 218:
# ----------------------------------------
# serratiopeptidase 15mg, nimesulide 100mg
#
# Cluster 23:
# ----------------------------------------
# nimesulide 1%
#
# Cluster 229:
# ----------------------------------------
# nimesulide 50mg/5ml
#
# Cluster 20:
# ----------------------------------------
# cholecalciferol 500iu, elemental calcium 500mg
#
# Cluster 18:
# ----------------------------------------
# calcium 200mg, vitamin d 3125iu
#
# Cluster 21:
# ----------------------------------------
# calcium carbonate 200mg, cholecalciferol 125iu
#
# Cluster 19:
# ----------------------------------------
# elemental calcium 500mg, vitamin d 3500iu
#
# Cluster 274:
# ----------------------------------------
# risperidone 1mg
#
# Cluster 275:
# ----------------------------------------
# risperidone 2mg
#
# Cluster 272:
# ----------------------------------------
# risperidone 3mg
#
# Cluster 273:
# ----------------------------------------
# risperidone 4mg
#
# Cluster 271:
# ----------------------------------------
# risperidone 4mg, trihexyphenidyl 2mg
# risperidone 2mg, trihexyphenidyl 2mg
# risperidone 3mg, trihexyphenidyl 2mg
#
# Cluster 269:
# ----------------------------------------
# risperidone 1mg/ml
#
# Cluster 270:
# ----------------------------------------
# risperidone 0.5mg
#
# Cluster 212:
# ----------------------------------------
# vecuronium 10mg
#
# Cluster 216:
# ----------------------------------------
# vecuronium bromide
#
# Cluster 213:
# ----------------------------------------
# vecuronium 20mg
#
# Cluster 214:
# ----------------------------------------
# vecuronium 4mg
#
# Cluster 189:
# ----------------------------------------
# ofloxacin 0.3%, dexamethasone 0.1%
#
# Cluster 250:
# ----------------------------------------
# ofloxacin 100mg
#
# Cluster 254:
# ----------------------------------------
# ofloxacin 200mg
#
# Cluster 252:
# ----------------------------------------
# ofloxacin 300mg
#
# Cluster 253:
# ----------------------------------------
# ofloxacin 400mg
#
# Cluster 251:
# ----------------------------------------
# ofloxacin 50mg
#
# Cluster 248:
# ----------------------------------------
# cefixime 100mg, ofloxacin 100mg
#
# Cluster 255:
# ----------------------------------------
# ofloxacin 100mg, cefixime 100mg
#
# Cluster 249:
# ----------------------------------------
# cefixime 200mg, ofloxacin 200mg
#
# Cluster 197:
# ----------------------------------------
# cefixime, ofloxacin
#
# Cluster 242:
# ----------------------------------------
# cefixime 50mg/5ml, ofloxacin 50mg/5ml
#
# Cluster 190:
# ----------------------------------------
# ofloxacin 0.3%
#
# Cluster 239:
# ----------------------------------------
# ofloxacin 100mg/5ml
# ofloxacin 50mg/5ml
#
# Cluster 256:
# ----------------------------------------
# ofloxacin 200mg, sodium chloride 900mg
#
# Cluster 240:
# ----------------------------------------
# ofloxacin 50mg/5ml, metronidazole 100mg/5ml
# ofloxacin 100mg/5ml, metronidazole 200mg/5ml
#
# Cluster 243:
# ----------------------------------------
# metronidazole 200mg, ofloxacin 100mg
# metronidazole 100mg, ofloxacin 50mg
#
# Cluster 244:
# ----------------------------------------
# ofloxacin 100mg, metronidazole
#
# Cluster 194:
# ----------------------------------------
# ofloxacin, metronidazole
#
# Cluster 245:
# ----------------------------------------
# ofloxacin 200mg, metronidazole 600mg
#
# Cluster 195:
# ----------------------------------------
# metronidazole, ofloxacin
#
# Cluster 246:
# ----------------------------------------
# ofloxacin 200mg, ornidazole 500mg
#
# Cluster 241:
# ----------------------------------------
# ofloxacin 50mg/5ml, ornidazole 125mg/5ml
#
# Cluster 196:
# ----------------------------------------
# ofloxacin, ornidazole
#
# Cluster 191:
# ----------------------------------------
# ofloxacin 5ml
#
# Cluster 247:
# ----------------------------------------
# ofloxacin 200mg, tinidazole 600mg
#
# Cluster 238:
# ----------------------------------------
# tinidazole 600mg, ofloxacin 200mg
#
# Cluster 35:
# ----------------------------------------
# bacillus clausii 2b
#
# Cluster 36:
# ----------------------------------------
# bacillus clausii 2billion
#
# Cluster 39:
# ----------------------------------------
# saccharomyces boulardii 5billion, bacillus subtilis 1billion
#
# Cluster 37:
# ----------------------------------------
# bacillus clausii 2billion spores
#
# Cluster 5:
# ----------------------------------------
# insulin pen
#
# Cluster 1:
# ----------------------------------------
# human insulin 100iu
# insulin human 100iu
#
# Cluster 4:
# ----------------------------------------
# insulin glargine 100iu
#
# Cluster 3:
# ----------------------------------------
# insulin isophane 70%, human insulin 30%
#
# Cluster 2:
# ----------------------------------------
# human insulin 100iu/ml
#
# Cluster 201:
# ----------------------------------------
# fluconazole 0.5% w
#
# Cluster 199:
# ----------------------------------------
# fluconazole 0.3%
#
# Cluster 202:
# ----------------------------------------
# fluconazole 0.5%
#
# Cluster 207:
# ----------------------------------------
# clotrimazole 1%
#
# Cluster 208:
# ----------------------------------------
# clotrimazole 1% w
#
# Cluster 232:
# ----------------------------------------
# fluconazole 100mg
#
# Cluster 230:
# ----------------------------------------
# fluconazole 150mg
#
# Cluster 203:
# ----------------------------------------
# fluconazole 2%
#
# Cluster 231:
# ----------------------------------------
# fluconazole 200mg
#
# Cluster 233:
# ----------------------------------------
# fluconazole 400mg
#
# Cluster 234:
# ----------------------------------------
# fluconazole 50mg
#
# Cluster 236:
# ----------------------------------------
# azithromycin 1mg, fluconazole 150mg, secnidazole 1mg
# azithromycin 1mg, fluconazole 150mg, secnidazole 2mg
#
# Cluster 237:
# ----------------------------------------
# fluconazole 150mg, azithromycin 1000mg, secnidazole 1000mg
#
# Cluster 200:
# ----------------------------------------
# fluconazole 0.3% w
#
# Cluster 8:
# ----------------------------------------
# ketoconazole 2%, zinc pyrithione 1%
# pyrithione zinc 1%, ketoconazole 2%
#
# Cluster 205:
# ----------------------------------------
# luliconazole 1%
#
# Cluster 206:
# ----------------------------------------
# luliconazole 1% w
#
# Cluster 9:
# ----------------------------------------
# fluconazole 2%, pyrithione zinc 1%
#
# Cluster 204:
# ----------------------------------------
# fluconazole
#
# Cluster 235:
# ----------------------------------------
# fluconazole 150mg, tinidazole 1000mg
#
# Cluster 12:
# ----------------------------------------
# pimecrolimus 1%
#
# Cluster 30:
# ----------------------------------------
# pimecrolimus
#
# Cluster 13:
# ----------------------------------------
# pimecrolimus 1% w
#
# Cluster 14:
# ----------------------------------------
# sodium picosulfate 5mg/5ml
#
# Cluster 15:
# ----------------------------------------
# sodium picosulfate 5mg
#
# Cluster 16:
# ----------------------------------------
# sodium picosulfate 3.33mg, liquid paraffin 1.25ml, milk of magnesia 3.75ml
#
# Cluster 17:
# ----------------------------------------
# liquid paraffin 1.25ml, magnesium hydroxide 3.75ml, sodium picosulfate 3.33mg
#
# Cluster 290:
# ----------------------------------------
# ibuprofen 250mg
#
# Cluster 291:
# ----------------------------------------
# ibuprofen 100mg
#
# Cluster 307:
# ----------------------------------------
# cetirizine 1mg
#
# Cluster 305:
# ----------------------------------------
# cetirizine 10mg
#
# Cluster 303:
# ----------------------------------------
# cetirizine hydrochloride 10mg
#
# Cluster 306:
# ----------------------------------------
# cetirizine 5mg
#
# Cluster 304:
# ----------------------------------------
# cetirizine hydrochloride 5mg/5ml
#
# Cluster 88:
# ----------------------------------------
# cetirizine 2.5mg/5ml, paracetamol 250mg/5ml, phenylephrine 2.5mg/5ml
#
# Cluster 86:
# ----------------------------------------
# cetirizine 2.5mg, paracetamol 125mg, phenylephrine 2.5mg
#
# Cluster 87:
# ----------------------------------------
# phenylephrine 2.5mg, cetirizine 2.5mg, paracetamol 125mg
#
# Cluster 318:
# ----------------------------------------
# aspirin 300mg
#
# Cluster 315:
# ----------------------------------------
# aspirin 50mg
#
# Cluster 317:
# ----------------------------------------
# aspirin 75mg
#
# Cluster 316:
# ----------------------------------------
# aspirin 100mg
#
# Cluster 259:
# ----------------------------------------
# ciprofloxacin 10mg
#
# Cluster 261:
# ----------------------------------------
# ciprofloxacin 500mg
#
# Cluster 260:
# ----------------------------------------
# ciprofloxacin 200mg
#
# Cluster 262:
# ----------------------------------------
# ciprofloxacin 100ml
#
# Cluster 263:
# ----------------------------------------
# ciprofloxacin
#
# Cluster 344:
# ----------------------------------------
# metformin 1000mg
#
# Cluster 345:
# ----------------------------------------
# metformin 500mg
#
# Cluster 346:
# ----------------------------------------
# glimepiride 1mg
#
# Cluster 347:
# ----------------------------------------
# glimepiride 2mg
#
# Cluster 338:
# ----------------------------------------
# amlodipine 5mg, atenolol 50mg
#
# Cluster 339:
# ----------------------------------------
# amlodipine 5mg
#
# Cluster 348:
# ----------------------------------------
# betamethasone 0.5mg
#
# Cluster 349:
# ----------------------------------------
# betamethasone 4mg
#
# Cluster 193:
# ----------------------------------------
# clindamycin 1%
#
# Cluster 354:
# ----------------------------------------
# hydrocortisone 100mg
#
# Cluster 319:
# ----------------------------------------
# ranitidine 150mg
#
# Cluster 320:
# ----------------------------------------
# ranitidine 50mg
#
# Cluster 321:
# ----------------------------------------
# ranitidine 20mg
#
# Cluster 334:
# ----------------------------------------
# omeprazole 20mg
#
# Cluster 192:
# ----------------------------------------
# azithromycin 100mg
#
# Cluster 198:
# ----------------------------------------
# cetirizine

# %%
df.to_csv('medlr_assignment_dataset_processed.csv', index=False)
